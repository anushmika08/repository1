# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science Salary 2021 to 2023.csv')
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
df.shape
# Out:
# (3761, 9)

# %%
df.size
# Out:
# 33849

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    work_year experience_level employment_type          job_title  salary  \
# 0       2023               EN              FT  Applied Scientist  213660
# 1       2023               EN              FT  Applied Scientist  130760
#
#   salary_currency  salary_in_usd company_location company_size
# 0             USD         213660               US            L
# 1             USD         130760               US            L

# %%
df.tail(2)
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
df.duplicated().sum()
# Out:
# 1351

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
df.isna().sum()
# Out:
# work_year           0
# experience_level    0
# employment_type     0
# job_title           0
# salary              0
# salary_currency     0
# salary_in_usd       0
# company_location    0
# company_size        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2410 entries, 0 to 3760
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         2410 non-null   int64
#  1   experience_level  2410 non-null   object
#  2   employment_type   2410 non-null   object
#  3   job_title         2410 non-null   object
#  4   salary            2410 non-null   int64
#  5   salary_currency   2410 non-null   object
#  6   salary_in_usd     2410 non-null   int64
#  7   company_location  2410 non-null   object
#  8   company_size      2410 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 188.3+ KB

# %%
for i in df.columns:

  print(df[i].unique(),i)

  print('_'*100)

  print(df[i].value_counts(),i)

  print('_'*100)
# Out:
# [2023 2022 2021 2020] work_year
# ____________________________________________________________________________________________________
# work_year
# 2023    1072
# 2022    1036
# 2021     227
# 2020      75
# Name: count, dtype: int64 work_year
# ____________________________________________________________________________________________________
# ['EN' 'EX' 'MI' 'SE'] experience_level
# ____________________________________________________________________________________________________
# experience_level
# SE    1417
# MI     631
# EN     267
# EX      95
# Name: count, dtype: int64 experience_level
# ____________________________________________________________________________________________________
# ['FT' 'PT' 'CT' 'FL'] employment_type
# ____________________________________________________________________________________________________
# employment_type
# FT    2373
# PT      17
# CT      10
# FL      10
# Name: count, dtype: int64 employment_type
# ...

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()

labelfit = le.fit(df['experience_level'])

df['experience_level'] = labelfit.transform(df['experience_level'])

df.head()
# Out:
#    work_year  experience_level employment_type                job_title  \
# 0       2023                 0              FT        Applied Scientist
# 1       2023                 0              FT        Applied Scientist
# 2       2023                 0              FT     Data Quality Analyst
# 3       2023                 0              FT  Compliance Data Analyst
# 4       2023                 0              FT        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()

labelfit = le.fit(df['employment_type'])

df['employment_type'] = labelfit.transform(df['employment_type'])

df.head()
# Out:
#    work_year  experience_level  employment_type                job_title  \
# 0       2023                 0                2        Applied Scientist
# 1       2023                 0                2        Applied Scientist
# 2       2023                 0                2     Data Quality Analyst
# 3       2023                 0                2  Compliance Data Analyst
# 4       2023                 0                2        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()

labelfit = le.fit(df['job_title'])

df['job_title'] = labelfit.transform(df['job_title'])

df.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2023                 0                2          8  213660
# 1       2023                 0                2          8  130760
# 2       2023                 0                2         41  100000
# 3       2023                 0                2         22   30000
# 4       2023                 0                2          8  204620
#
#   salary_currency  salary_in_usd company_location company_size
# 0             USD         213660               US            L
# 1             USD         130760               US            L
# 2             USD         100000               NG            L
# 3             USD          30000               NG            L
# 4             USD         204620               US            L

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()

labelfit = le.fit(df['salary_currency'])

df['salary_currency'] = labelfit.transform(df['salary_currency'])

df.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2023                 0                2          8  213660
# 1       2023                 0                2          8  130760
# 2       2023                 0                2         41  100000
# 3       2023                 0                2         22   30000
# 4       2023                 0                2          8  204620
#
#    salary_currency  salary_in_usd company_location company_size
# 0               19         213660               US            L
# 1               19         130760               US            L
# 2               19         100000               NG            L
# 3               19          30000               NG            L
# 4               19         204620               US            L

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()

labelfit = le.fit(df['company_location'])

df['company_location'] = labelfit.transform(df['company_location'])

df.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2023                 0                2          8  213660
# 1       2023                 0                2          8  130760
# 2       2023                 0                2         41  100000
# 3       2023                 0                2         22   30000
# 4       2023                 0                2          8  204620
#
#    salary_currency  salary_in_usd  company_location company_size
# 0               19         213660                70            L
# 1               19         130760                70            L
# 2               19         100000                53            L
# 3               19          30000                53            L
# 4               19         204620                70            L

# %%
def convert_company_size(size):
    if size == 'S':
        return 0
    elif size == 'M':
        return 1
    elif size == 'L':
        return 2
    else:
        return 3

# %%
df['company_size'] = df['company_size'].apply(convert_company_size)

df.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2023                 0                2          8  213660
# 1       2023                 0                2          8  130760
# 2       2023                 0                2         41  100000
# 3       2023                 0                2         22   30000
# 4       2023                 0                2          8  204620
#
#    salary_currency  salary_in_usd  company_location  company_size
# 0               19         213660                70             3
# 1               19         130760                70             3
# 2               19         100000                53             3
# 3               19          30000                53             3
# 4               19         204620                70             3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2410 entries, 0 to 3760
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         2410 non-null   int64
#  1   experience_level  2410 non-null   int64
#  2   employment_type   2410 non-null   int64
#  3   job_title         2410 non-null   int64
#  4   salary            2410 non-null   int64
#  5   salary_currency   2410 non-null   int64
#  6   salary_in_usd     2410 non-null   int64
#  7   company_location  2410 non-null   int64
#  8   company_size      2410 non-null   int64
# dtypes: int64(9)
# memory usage: 188.3 KB

# %%
df.corr()
# Out:
#                   work_year  experience_level  employment_type  job_title  \
# work_year          1.000000          0.212935         0.008985  -0.031860
# experience_level   0.212935          1.000000        -0.042484   0.030581
# employment_type    0.008985         -0.042484         1.000000  -0.057585
# job_title         -0.031860          0.030581        -0.057585   1.000000
# salary            -0.099553         -0.019796        -0.002963   0.035140
# salary_currency    0.246748          0.216426        -0.057153  -0.050819
# salary_in_usd      0.242721          0.354363        -0.014143   0.107345
# company_location   0.218864          0.241167        -0.020468  -0.062473
# company_size            NaN               NaN              NaN        NaN
#
#                     salary  salary_currency  salary_in_usd  company_location  \
# work_year        -0.099553         0.246748       0.242721          0.218864
# ...

# %% [markdown]
# #Bar plot

# %%
import matplotlib.pyplot as plt

import seaborn as sns


plt.figure(figsize=(10, 6))

sns.barplot(x='experience_level',y='salary_in_usd', data=df)

plt.title('Salary vs Experience Level')

plt.xlabel('Experience Level')


plt.ylabel('Salary in USD')


plt.show()

# %% [markdown]
# #Pie Plot

# %%
data =df.groupby('experience_level')['experience_level'].count()
data
# Out:
# experience_level
# 0     267
# 1      95
# 2     631
# 3    1417
# Name: experience_level, dtype: int64

# %%
plt.pie(data,labels=data.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7b1592f82710>,
# ...
#  [Text(1.0340427962247825, 0.3751739537542991, '0'),
#   Text(0.7504894458274836, 0.8042173783881797, '1'),
#   Text(-0.2137203653169642, 1.079038278027607, '2'),
#   Text(-0.3001366778853995, -1.058261770351701, '3')],
#  [Text(0.5640233433953359, 0.2046403384114359, '11.1%'),
#   Text(0.4093578795422637, 0.43866402457537074, '3.9%'),
#   Text(-0.1165747447183441, 0.5885663334696039, '26.2%'),
#   Text(-0.16371091521021788, -0.5772336929191095, '58.8%')])

# %% [markdown]
# #Scatter Plot

# %%
import matplotlib.pyplot as plt
import pandas as pd

x_column='employment_type'
y_column='salary_in_usd'

plt.scatter(x=df[x_column],y=df[y_column],color='r')
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('employement_type vs salary_in_usd')
plt.grid(True,color='k')

plt.show()

# %% [markdown]
# #Heat Map

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #Line Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10, 6))
sns.lineplot(x='experience_level', y='salary_in_usd', data=df)
plt.title('Salary vs Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary in usd')
plt.show()

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10, 6))
sns.boxplot(x='company_size', y='salary_in_usd', data=df)
plt.title('Salary Distribution by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Salary in USD')
plt.show()

# %% [markdown]
# # Violin Plot

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
sns.violinplot(x='company_size', y='salary_in_usd', data=df)
plt.title('Salary Distribution by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Salary in USD')
plt.show()
